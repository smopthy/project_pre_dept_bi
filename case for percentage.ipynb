# %%
import random
import string
import pandas as pd
import numpy as np

# %%
np.random.seed(0)
# This is the total number of groups to be created
NumberOfGroups = 50000

# Create a lot of groups (random strings of 4 letters)
Group1     = [''.join(random.choice(string.ascii_uppercase) for _ in range(4)) for x in range(NumberOfGroups//10)]*10
Group2     = [''.join(random.choice(string.ascii_uppercase) for _ in range(4)) for x in range(NumberOfGroups//2)]*2
FinalGroup = [''.join(random.choice(string.ascii_uppercase) for _ in range(4)) for x in range(NumberOfGroups)]

# Make the numbers
NumbersForPercents = [np.random.randint(100, 999) for _ in range(NumberOfGroups)]

# Make the dataframe
df = pd.DataFrame({'Group 1': Group1,
                   'Group 2': Group2,
                   'Final Group': FinalGroup,
                   'Numbers I want as percents': NumbersForPercents})
# Out:
# ['HMQT',
#  'WJHD',
#  'GYHB',
#  'TATS',
#  'FMEE',
#  'UIBJ',
#  'LIKF',
#  'TZNP',
#  'NQAQ',
#  'XZZA',
#  'CTGH',
#  'ASRX',
#  'CNQV',
#  'CWLB',
#  'QEFX',
#  'LJGU',
#  'ZUZR',
#  'AVGX',
#  'JCLB',
#  'ZCOM',
#  'RBVN',
#  'MGFA',
#  'TMPN',
#  'MKMW',
#  'UBWI',
#  'PTNP',
#  'CCTR',
#  'PEAT',
#  'TAUC',
#  'TUFJ',
#  'GYYJ',
#  'KINQ',
#  'IOMW',
#  'MYLU',
#  'LPPS',
#  'BROA',
#  'MKHN',
#  'VJTE',
#  'OVSV',
#  'TRDM',
#  'KIMJ',
#  'GKKM',
#  'LEFP',
#  'IRMJ',
#  'EFJN',
#  'RAPZ',
#  'NFKA',
#  'IBMI',
#  'AJVL',
#  'NDUX',
#  'ZJVS',
#  'GOEI',
#  'RMIN',
#  'SLVM',
#  'QWTI',
#  'SRCJ',
#  'UIGC',
#  'LDYB',
#  'FDEX',
#  'MGLQ',
#  'QCKT',
#  'RELL',
#  'SYBY',
#  'SUWQ',
#  'RLVR',
#  'QAGU',
#  'GZGD',
#  'FDHI',
#  'ONBK',
#  'OOKC',
#  'MMGV',
#  'LDAX',
#  'AKZV',
#  'ZPOU',
#  'OCAS',
#  'MBHB',
#  'RLSI',
#  'ZJYO',
#  'RLHS',
#  'UEHX',
#  'GRVJ',
#  'XFYD',
#  'VJAA',
#  'XKZF',
#  'VFKK',
#  'KLBG',
#  'FQKE',
#  'XXQL',
#  'QLWZ',
#  'PMMC',
#  'NWPO',
#  'ODUW',
#  'MYSU',
#  'ADHO',
#  'GRPL',
#  'DGDQ',
#  'QFFC',
#  'AADB',
#  'MWAO',
#  'MOXX',
#  'OVQR',
#  'YRNX',
#  'QWJG',
#  'SNWW',
#  'XSGZ',
#  'ROEN',
#  'MEKS',
#  'BOIC',
#  'RTYV',
#  'UGCK',
#  'NQZV',
#  'JNSF',
#  'ISCD',
#  'HOYO',
#  'YFIG',
#  'OSOW',
#  'NILT',
#  'ZXJW',
#  'UJCC',
#  'MNDK',
#  'MGOQ',
#  'PHKM',
#  'KANK',
#  'IXFE',
#  'EKTV',
#  'FLYR',
#  'QQEV',
#  'UERB',
#  'UZJP',
#  'RWOJ',
#  'IJQI',
#  'MJVC',
#  'BGDB',
#  'HCNX',
#  'RMRA',
#  'LIPN',
#  'CWTG',
#  'BSUG',
#  'VNTT',
#  'FAZH',
#  'ZVEJ',
#  'HZNC',
#  'MRSF',
#  'PSHY',
#  'GUVL',
#  'YUVF',
#  'VPJP',
#  'XPXM',
#  'LKMF',
#  'MRML',
#  'RBKH',
#  'UXOH',
#  'ZCKN',
#  'XNVC',
#  'SCKH',
#  'GKCR',
#  'BHFC',
#  'OKFL',
#  'LSSF',
#  'KXWO',
#  'TIMA',
#  'FDFX',
#  'LSIN',
#  'LALZ',
#  'BXNO',
#  'MIRL',
#  'SDNF',
#  'GYGK',
#  'FAMJ',
#  'SGFU',
#  'BNLO',
#  'IBLY',
#  'SSLF',
#  'CVIV',
#  'EUVA',
#  'TGQW',
#  'BAKR',
#  'YQVQ',
#  'NAUY',
#  'QMGZ',
#  'ARJI',
#  'ODPQ',
#  'KTOQ',
#  'PGEM',
#  'MAPM',
#  'JSSB',
#  'LKYK',
#  'JBMO',
#  'EQDP',
#  'NKRB',
#  'OFMX',
#  'NAVT',
#  'MQNX',
#  'DNVZ',
#  'TJDF',
#  'XOML',
#  'GPYR',
#  'PFYK',
#  'UYGR',
#  'WMON',
#  'THSA',
#  'ZKZQ',
#  'BLPE',
#  'AIPV',
#  'VKRV',
#  'YUKN',
#  'RBNP',
#  'ZCRL',
#  'MJQL',
#  'TWRX',
#  'WJQM',
#  'PXKV',
#  'CMHM',
#  'UBKI',
#  'OTBM',
#  'DLCS',
#  'OAKF',
#  'CEQO',
#  'HRLL',
#  'WIAM',
#  'LUIO',
#  'UXIZ',
#  'SMQX',
#  'RSFV',
#  'EHJG',
#  'CEZS',
#  'ZYCW',
#  'BELV',
#  'RUQU',
#  'EQLF',
#  'ECHB',
#  'BSHE',
#  'OSBC',
#  'SRSH',
#  'HLFE',
#  'PXQW',
#  'XHLI',
#  'LGHZ',
#  'IBDJ',
#  'OUDG',
#  'AUCN',
#  'EEGU',
#  'LFQH',
#  'ONBA',
#  'PNJK',
#  'YNCU',
#  'BSQT',
#  'RSIF',
#  'QOKN',
#  'SQRM',
#  'NLJT',
#  'COPR',
#  'WSAJ',
#  'PREU',
#  'LTMI',
#  'HTAX',
#  'QVQM',
#  'BPLN',
#  'VGTB',
#  'DKTS',
#  'XKCM',
#  'IWFQ',
#  'VVHO',
#  'VKPV',
#  'FEVN',
#  'SSNI',
#  'LDJA',
#  'GOXL',
#  'KDPK',
#  'BBEX',
#  'IISO',
#  'KGQI',
#  'LTMI',
#  'IWPV',
#  'IMFZ',
#  'NQVX',
#  'UBHX',
#  'GQHV',
#  'SVDG',
#  'QXOL',
#  'BRME',
#  'CYNW',
#  'LRPM',
#  'UHHW',
#  'AGZI',
#  'QJPR',
#  'FBDV',
#  'UWGX',
#  'OSZL',
#  'YMEV',
#  'SMAI',
#  'JZQB',
#  'ACGT',
#  'VMEE',
#  'MBGX',
#  'NDLX',
#  'VXUF',
#  'RFUS',
#  'OZPU',
#  'ROQZ',
#  'RKUM',
#  'MEUK',
#  'KKDB',
#  'KWFU',
#  'PQTJ',
#  'JNLR',
#  'YCZQ',
#  'WZFB',
#  'VKII',
#  'RAVK',
#  'SPLZ',
#  'JSFY',
#  'ARWK',
#  'BHUV',
#  'LYMV',
#  'JCUJ',
#  'NCBX',
#  'KJZI',
#  'NXNU',
#  'NQQG',
#  'HPTF',
#  'YFQB',
#  'VCSA',
#  'YBUS',
#  'AROM',
#  'UOYS',
#  'MDRZ',
#  'TIJO',
#  'WYZO',
#  'EEAZ',
#  'ZVDJ',
#  'XRUI',
#  'IKVE',
#  'CVRE',
#  'NWQS',
#  'UDMP',
#  'OYZC',
#  'XMYZ',
#  'OUSP',
#  'EYCS',
#  'KFEP',
#  'ZIRQ',
#  'VKHR',
#  'VCPB',
#  'GSPX',
#  'OWHG',
#  'NGMN',
#  'LIEZ',
#  'TSNG',
#  'UJZD',
#  'DFKM',
#  'MAXK',
#  'UIVN',
#  'INFY',
#  'PEGI',
#  'YZKH',
#  'CJJT',
#  'YEQP',
#  'ZGVD',
#  'YZAN',
#  'OQYI',
#  'SUUX',
#  'OMHM',
#  'IRTN',
#  'DWDX',
#  'PCKJ',
#  'IZVK',
#  'QCUC',
#  'KZUC',
#  'PUCJ',
#  'MGEV',
#  'HNRH',
#  'GESA',
#  'YGSQ',
#  'AJVH',
#  'ZOBG',
#  'OZXU',
#  'NFHQ',
#  'USBI',
#  'LODI',
#  'XORY',
#  'GRXM',
#  'XXKP',
#  'JAQN',
#  'ZSYB',
#  'FPEG',
#  'RJDW',
#  'MENM',
#  'UAGW',
#  'MTMA',
#  'VDJV',
#  'UKPJ',
#  'DXQY',
#  'KRDY',
#  'LWXW',
#  'FJRJ',
#  'NHBY',
#  'UQUC',
#  'NHDQ',
#  'CAYO',
#  'DPFC',
#  'RQWM',
#  'OLIB',
#  'TETH',
#  'DVSG',
#  'GGGQ',
#  'ZEFU',
#  'RLLL',
#  'RGYX',
#  'OEWF',
#  'TRKP',
#  'PBNS',
#  'KUTB',
#  'QYJE',
#  'NGHB',
#  'FYHB',
#  'GERW',
#  'HWAK',
#  'WIIR',
#  'EANI',
#  'YCDP',
#  'UBID',
#  'LOPC',
#  'YAOI',
#  'KQXK',
#  'NLKE',
#  'BFJW',
#  'MGES',
#  'WUQW',
#  'XLVD',
#  'ELLX',
#  'XEQP',
#  'PLSU',
#  'LEOS',
#  'MJQB',
#  'JEZG',
#  'RWOV',
#  'MXQI',
#  'FNSW',
#  'WTLT',
#  'RCYI',
#  'EBWA',
#  'CTLH',
#  'PXWP',
#  'UPEK',
#  'RNJF',
#  'QVMW',
#  'CRIF',
#  'EBGM',
#  'YHIE',
#  'UIET',
#  'YXHD',
#  'SGAL',
#  'RYYN',
#  'TCFB',
#  'YBEI',
#  'LMFL',
#  'HWSL',
#  'RSRA',
#  'XKBR',
#  'QKLU',
#  'IKGF',
#  'IHPS',
#  'DCNX',
#  'BEOF',
#  'RUUY',
#  'UKRG',
#  'LLIL',
#  'MDQT',
#  'DBWX',
#  'EHBM',
#  'FFQK',
#  'RVPC',
#  'KUAY',
#  'VUUO',
#  'QQGX',
#  'PCIA',
#  'LWZX',
#  'BZOP',
#  'EFWM',
#  'ZCOS',
#  'VPWE',
#  'EEZL',
#  'MEDQ',
#  'WZXW',
#  'SFWN',
#  'FUPJ',
#  'IHLB',
#  'BAFS',
#  'BNBU',
#  'HPAR',
#  'HJSE',
#  'HRAC',
#  'VKUC',
#  'DLOW',
#  'AHXP',
#  'GORW',
#  'FMJO',
#  'IWNG',
#  'DNGR',
#  'OYBG',
#  'YDHZ',
#  'EDEP',
#  'HLTE',
#  'QSEF',
#  'XCFV',
#  'OICN',
#  'KAHT',
#  'CNBO',
#  'TPGQ',
#  'PITK',
#  'ZUOQ',
#  'MOQI',
#  'MAGS',
#  'UUAI',
#  'HYLU',
#  'CLUR',
#  'NGPS',
#  'LSYF',
#  'AAHK',
#  'CGVB',
#  'OTII',
#  'SEFR',
#  'XWEK',
#  'WION',
#  'JVBB',
#  'KCAB',
#  'MTSA',
#  'SCPC',
#  'LTTM',
#  'RLUX',
#  'KXLJ',
#  'MYOX',
#  'IWHG',
#  'LXDU',
#  'YXDH',
#  'NKVB',
#  'YOOX',
#  'PBDT',
#  'QNID',
#  'UASG',
#  'KXNF',
#  'XGSH',
#  'OBZB',
#  'MDUF',
#  'YHEF',
#  'BPUO',
#  'WDHT',
#  'TFGE',
#  'RSBS',
#  'ZQMQ',
#  'DYIP',
#  'KVUO',
#  'SUWD',
#  'FUPG',
#  'UTRH',
#  'GORH',
#  'NUVF',
#  'ZQHJ',
#  'MZRV',
#  'MKDR',
#  'EUZG',
#  'GQCS',
#  'INHC',
#  'AHLP',
#  'ZMPF',
#  'NJAP',
#  'FZJP',
#  'OVML',
#  'ZKGT',
#  'XDXG',
#  'KEFH',
#  'VOZH',
#  'VOME',
#  'GVWA',
#  'SJKO',
#  'JFRJ',
#  'MOUA',
#  'NXUB',
#  'KWGT',
#  'WJSU',
#  'CUFX',
#  'OAYA',
#  'ESSO',
#  'ZSPP',
#  'PKHF',
#  'MNNH',
#  'DHDW',
#  'CTEP',
#  'NLBE',
#  'LDBD',
#  'QRFF',
#  'MFOW',
#  'VUFY',
#  'ZBIX',
#  'UKVM',
#  'EAWE',
#  'OTNU',
#  'BBJJ',
#  'QVSG',
#  'KVAS',
#  'DYWD',
#  'DHIB',
#  'ONUL',
#  'XQMW',
#  'AZEE',
#  'DXQW',
#  'GJML',
#  'MDSB',
#  'SPLL',
#  'JPKM',
#  'KZDS',
#  'GKEB',
#  'GWAZ',
#  'AOPQ',
#  'QGRM',
#  'NEEA',
#  'VMQJ',
#  'BVCU',
#  'BUPW',
#  'QTJR',
#  'GNQG',
#  'HNJM',
#  'JQGX',
#  'VAXA',
#  'EZOM',
#  'AHJL',
#  'QMTL',
#  'OSDQ',
#  'GSEO',
#  'YLAD',
#  'RPGG',
#  'AQFV',
#  'EGTW',
#  'JLAZ',
#  'PQXE',
#  'PXXS',
#  'QRFK',
#  'TKLR',
#  'DPJW',
#  'NWTB',
#  'BOJB',
#  'ZRQU',
#  'EGLM',
#  'FRHR',
#  'CJWT',
#  'NYOF',
#  'ENCN',
#  'BZDE',
#  'VRYT',
#  'SIKX',
#  'PBXJ',
#  'IXPJ',
#  'UDGA',
#  'GWUR',
#  'HZHR',
#  'TLFO',
#  'RIXV',
#  'AVNH',
#  'YCMM',
#  'MZPD',
#  'VGSQ',
#  'UGAP',
#  'OMXK',
#  'JKHY',
#  'ECDG',
#  'ZAYN',
#  'BKQU',
#  'HKRQ',
#  'DWAN',
#  'OIUT',
#  'GXKZ',
#  'YCTX',
#  'ASRB',
#  'KVGN',
#  'SDOL',
#  'WBFQ',
#  'NEHI',
#  'NUPQ',
#  'ZXEL',
#  'RETG',
#  'XJLF',
#  'XOJX',
#  'ZYGB',
#  'EXHL',
#  'FKOK',
#  'XAAM',
#  'OYKM',
#  'MUFB',
#  'MZLE',
#  'PGPL',
#  'YLWX',
#  'COYK',
#  'HBCN',
#  'PINV',
#  'HDMC',
#  'PYMD',
#  'GRBE',
#  'EFGZ',
#  'QHVW',
#  'RCOQ',
#  'TNTB',
#  'PGXB',
#  'SXQT',
#  'VLYP',
#  'HTIZ',
#  'EWAD',
#  'PWTP',
#  'NYZN',
#  'LOBU',
#  'NQBO',
#  'XLJW',
#  'OQHX',
#  'LPZF',
#  'HJKI',
#  'BQSS',
#  'XNFA',
#  'NOGU',
#  'LMEC',
#  'ITRE',
#  'YHEP',
#  'SRUG',
#  'UCNJ',
#  'YZFH',
#  'SEGV',
#  'MFEL',
#  'WQEV',
#  'SHOJ',
#  'SWOW',
#  'ZOXF',
#  'URDI',
#  'TYVG',
#  'NUEB',
#  'VJQX',
#  'MRTY',
#  'FFXR',
#  'XCMG',
#  'NXYB',
#  'FHRA',
#  'UIWQ',
#  'GVXU',
#  'HUUS',
#  'LARH',
#  'IFSV',
#  'TNPN',
#  'VADN',
#  'XXAD',
#  'LLCH',
#  'IQDA',
#  'EFMI',
#  'KODD',
#  'QYTK',
#  'ZORM',
#  'JAQE',
#  'OGKX',
#  'PTWX',
#  'DCEP',
#  'IHTE',
#  'XIOI',
#  'HKMA',
#  'FJOG',
#  'HUMQ',
#  'ZFGV',
#  'WKGD',
#  'OVEA',
#  'ARAO',
#  'XZQK',
#  'UZJN',
#  'LUQE',
#  'UDYG',
#  'VWDM',
#  'NECB',
#  'JGHE',
#  'SFJJ',
#  'ZXXU',
#  'AFIJ',
#  'HCZN',
#  'GQTB',
#  'VHCC',
#  'PLUQ',
#  'ETOM',
#  'LGUC',
#  'CMLL',
#  'WWPR',
#  'LXDU',
#  'EFFK',
#  'QKFI',
#  'LDPS',
#  'MZRF',
#  'IWAC',
#  'TTHB',
#  'EKNS',
#  'EDSV',
#  'QYRN',
#  'BYJI',
#  'YTGF',
#  'NMWS',
#  'VQJR',
#  'LVJP',
#  'DWTR',
#  'WSLG',
#  'EMTW',
#  'FKRC',
#  'LRCX',
#  'UGVO',
#  'DYOG',
#  'OLRI',
#  'AURO',
#  'CPGC',
#  'ENCJ',
#  'BRXY',
#  'GLSK',
#  'JJYV',
#  'MFXZ',
#  'JMZU',
#  'FEHL',
#  'EGEA',
#  'AHYP',
#  'BONE',
#  'GSGL',
#  'RONC',
#  'NBHH',
#  'BXHJ',
#  'AUZH',
#  'JDDO',
#  'XTSJ',
#  'NYOY',
#  'HEEW',
#  'LKMA',
#  'KXGD',
#  'ZCSY',
#  'RFSY',
#  'EUGN',
#  'MLZA',
#  'MMYV',
#  'CDCJ',
#  'NPFU',
#  'DVWN',
#  'YOSU',
#  'PLMW',
#  'BBTE',
#  'CSHW',
#  'WWDN',
#  'LMXY',
#  'VAVC',
#  'JKIC',
#  'ROMO',
#  'ZJUS',
#  'NXQU',
#  'XEKL',
#  'RDAC',
#  'GNJJ',
#  'MWMK',
#  'LVPO',
#  'OBWC',
#  'THSF',
#  'NMUG',
#  'JBHC',
#  'HEST',
#  'HQQZ',
#  'UKLY',
#  'XFAE',
#  'XHRU',
#  'WCRD',
#  'ROYK',
#  'JQTU',
#  'DMBJ',
#  'JNTB',
#  'DCLS',
#  'VAEV',
#  'IHAB',
#  'BJCS',
#  'VQQJ',
#  'JAXG',
#  'KHGE',
#  'RARI',
#  'ICYE',
#  'LYEQ',
#  'BASF',
#  'VKIE',
#  'KIGA',
#  'MMFV',
#  'DSLW',
#  'OZOM',
#  'DYMI',
#  'BSXU',
#  'YQOL',
#  'BVVK',
#  'VCHK',
#  'SNSE',
#  'LBHN',
#  'KHDT',
#  'JYGS',
#  'DMXL',
#  'KCUX',
#  'PPEA',
#  'POFA',
#  'QQET',
#  'XUSI',
#  'RRIX',
#  'FWBF',
#  'BPGL',
#  'EGOM',
#  'UOEY',
#  'ZJGV',
#  'YFJP',
#  'HZQX',
#  'HMZT',
#  'UMMB',
#  'VNCL',
#  'MPKC',
#  'UOZG',
#  'CLAJ',
#  'AGIR',
#  'WHFF',
#  'SPYI',
#  'BSAO',
#  'CZRU',
#  'UVJW',
#  'ZYCT',
#  'XLKI',
#  'JMZO',
#  'YWCU',
#  'ZQWW',
#  'ZSBI',
#  'SSQZ',
#  'VLAI',
#  'LCBX',
#  'HJGH',
#  'WNMN',
#  'WXUV',
#  'WHKL',
#  'UYZQ',
#  'SRPU',
#  'JUIG',
#  'ZUCK',
#  'NDZT',
#  'LFRS',
#  'BNZW',
#  'SXJX',
#  'EMXW',
#  'JHHA',
#  'BFHV',
#  'ZETC',
#  'QHWQ',
#  'RZLV',
#  'QWEO',
#  'LDLL',
#  'QTUL',
#  'BLYW',
#  'XGKT',
#  'DUXS',
#  'MLOW',
#  'LMHI',
#  'HBBP',
#  'ILGV',
#  'TPBM',
#  'AWRO',
#  'SPAC',
#  'CFLU',
#  'VKPY',
#  'SFEF',
#  'NDXX',
#  'MYHR',
#  'KUSG',
#  'UFMY',
#  'HTVJ',
#  'KASU',
#  'NEPB',
#  'ITSF',
#  'WKBQ',
#  'FNLI',
#  'FPPZ',
#  'FBHI',
#  'GEBP',
#  'XGUJ',
#  'CTKV',
#  'HULU',
#  'SYSD',
#  'PALY',
#  'PGWW',
#  'NHNA',
#  'HBOH',
#  'QVNX',
#  'AUHV',
#  'LWTY',
#  'MNYR',
#  'YNNV',
#  'LOZU',
#  'RYAP',
#  'CWXY',
#  'BILS',
#  'UPEG',
#  'AXIA',
#  'BKVR',
#  'IAPT',
#  'UAZI',
#  'NBJU',
#  'TDUC',
#  'ICSG',
#  ...]

# %%
df.groupby(['Group 1','Group 2','Final Group'])

# %%
# Initial grouping (basically a sorted version of df)
PreGroupby_df = df.groupby(["Group 1","Group 2","Final Group"]).agg({'Numbers I want as percents': 'sum'}).reset_index()
# Get the sum of values for the "final group", append "_Sum" to it's column name, and change it into a dataframe (.reset_index)
SumGroup_df = df.groupby(["Group 1","Group 2"]).agg({'Numbers I want as percents': 'sum'}).add_suffix('_Sum').reset_index()
# Merge the two dataframes
Percents_df = pd.merge(PreGroupby_df, SumGroup_df)
# # Divide the two columns
Percents_df["Percent of Final Group"] = Percents_df["Numbers I want as percents"] / Percents_df["Numbers I want as percents_Sum"] * 100
# Drop the extra _Sum column
# Percents_df.drop(["Numbers I want as percents_Sum"], inplace=True, axis=1)

# %%
SumGroup_df.head()
# Out:
#   Group 1 Group 2  Numbers I want as percents_Sum
# 0    AACX    GKFI                             982
# 1    AACX    RDXR                             977
# 2    AACX    RFTZ                             836
# 3    AACX    ZTOW                            1312
# 4    AACX    ZVPV                            1264

# %%
PreGroupby_df.head()
# Out:
#   Group 1 Group 2 Final Group  Numbers I want as percents
# 0    AACX    GKFI        MMZW                         481
# 1    AACX    GKFI        OFMA                         501
# 2    AACX    RDXR        MLGJ                         714
# 3    AACX    RDXR        SKBB                         263
# 4    AACX    RFTZ        EZAJ                         727

# %%
Percents_df
# Out:
#       Group 1 Group 2 Final Group  Numbers I want as percents  \
# 0        AABZ    BCIZ        NPWF                         711
# 1        AABZ    BCIZ        UGND                         573
# 2        AABZ    GCSI        GNXA                         159
# 3        AABZ    GCSI        TSNV                         640
# 4        AABZ    JFBI        LVNG                         630
# ...       ...     ...         ...                         ...
# 49995    ZZYD    TEWR        ZHFN                         393
# 49996    ZZYD    TKDK        EOYC                         800
# 49997    ZZYD    TKDK        HSAO                         844
# 49998    ZZYD    VLZH        JQHK                         685
# 49999    ZZYD    VLZH        NWFI                         188
#
#        Numbers I want as percents_Sum  Percent of Final Group
# 0                                1284               55.373832
# 1                                1284               44.626168
# 2                                 799               19.899875
# 3                                 799               80.100125
# 4                                1010               62.376238
# ...                               ...                     ...
# 49995                            1369               28.707085
# 49996                            1644               48.661800
# 49997                            1644               51.338200
# 49998                             873               78.465063
# 49999                             873               21.534937
#
# [50000 rows x 6 columns]

# %%
state_office = df.groupby(['Group 1','Group 2','Final Group']).agg({'Numbers I want as percents': 'sum'})
state_pcts = state_office.groupby(level=['Group 1','Group 2']).apply(lambda x: 100 * x / float(x.sum()))

# %%
# state_office
state_pcts
# Out:
#                              Numbers I want as percents
# Group 1 Group 2 Final Group
# AABZ    BCIZ    NPWF                          55.373832
#                 UGND                          44.626168
#         GCSI    GNXA                          19.899875
#                 TSNV                          80.100125
#         JFBI    LVNG                          62.376238
# ...                                                 ...
# ZZYD    TEWR    ZHFN                          28.707085
#         TKDK    EOYC                          48.661800
#                 HSAO                          51.338200
#         VLZH    JQHK                          78.465063
#                 NWFI                          21.534937
#
# [50000 rows x 1 columns]
